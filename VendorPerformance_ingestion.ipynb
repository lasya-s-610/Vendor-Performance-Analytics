# %%
#INSERT MySQL Password IN [4]

# %%
#Libraries
import pandas as pd
import os

# %%
# !pip install sqlalchemy pymysql --quiet

# %%
from sqlalchemy import create_engine

# %%
from urllib.parse import quote_plus
MYSQL_db="inventory"
MYSQL_port="3306"
MYSQL_user="root"
MYSQL_host="localhost"
MYSQL_PASSWORD = "YOUR PASSWORD"
encoded_pw=quote_plus(MYSQL_PASSWORD)
engine = create_engine(f"mysql+pymysql://{MYSQL_user}:{encoded_pw}@{MYSQL_host}:{MYSQL_port}/{MYSQL_db}")

# %%
for file in os.listdir('Downloads/PowerBI projects/Vendor performance analysis/data'):
    print(file)
# Out:
# .ipynb_checkpoints
# begin_inventory.csv
# end_inventory.csv
# purchases.csv
# purchase_prices.csv
# sales.csv
# vendor_invoice.csv

# %%
def ingest_db(df,table_name,engine):
    df.to_sql(table_name,engine,if_exists='replace',index=False,chunksize=100000)

# %%
folder="C:\\Users\\LASYA\\Downloads\\PowerBI projects\\Vendor performance analysis\\data"
for file in os.listdir(folder):
    if ".csv" in file:
        df=pd.read_csv(folder+"\\"+file)
        print(df.shape)
        ingest_db(df,file[:-4],engine)
# Out:
# (206529, 9)
# (224489, 9)
# (2372474, 16)
# (12261, 9)
# (12825363, 14)
# (5543, 10)
